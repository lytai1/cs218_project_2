# %%
import pandas as pd

df = pd.read_csv("LifeExpectancyData_NewPopulation.csv")
df = df[df['percentage_expenditure']!= 0]
# df.to_csv("LifeExpectancyData_NewPopulation2.csv")
df
# Out:
#           Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 0     Afghanistan  2015  Developing             65.0              263
# 1     Afghanistan  2014  Developing             59.9              271
# 2     Afghanistan  2013  Developing             59.9              268
# 3     Afghanistan  2012  Developing             59.5              272
# 4     Afghanistan  2011  Developing             59.2              275
# ...           ...   ...         ...              ...              ...
# 2918     Zimbabwe  2009  Developing             50.0              587
# 2919     Zimbabwe  2008  Developing             48.2              632
# 2920     Zimbabwe  2007  Developing             46.6               67
# 2921     Zimbabwe  2006  Developing             45.4                7
# 2922     Zimbabwe  2005  Developing             44.6              717
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2918             30     4.64                1.040021         73.0      853
# 2919             30     3.56               20.843429         75.0        0
# 2920             29     3.88               29.814566         72.0      242
# 2921             28     4.57               34.262169         68.0      212
# 2922             28     4.14                8.717409         65.0      420
#
#       ...  Polio  Total_expenditure  Diphtheria  HIV_AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2918  ...   69.0               6.26        73.0      18.1   65.824121
# 2919  ...   75.0               4.96        75.0      20.5  325.678573
# 2920  ...   73.0               4.47        73.0      23.7  396.998217
# 2921  ...   71.0               5.12         7.0      26.8  414.796232
# 2922  ...   69.0               6.44        68.0      30.3  444.765750
#
#       Population  thinness_10_19_years  thinness_5_9_years  \
# 0     33736494.0                  17.2                17.3
# 1     32758020.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3     30696958.0                  17.9                18.0
# 4     29708599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2918  13810599.0                   7.5                 7.4
# 2919  13558469.0                   7.8                 7.8
# 2920  13329909.0                   8.2                 8.2
# 2921  13124267.0                   8.6                 8.6
# 2922  12940032.0                   9.0                 9.0
#
#       Income_composition_of_resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2918                            0.419        9.9
# 2919                            0.421        9.7
# 2920                            0.414        9.6
# 2921                            0.408        9.5
# 2922                            0.406        9.3
#
# [2322 rows x 22 columns]

# %%
df.drop(["Country", "Year"], axis=1, inplace=True)
df.dropna(inplace=True)
df
# Out:
#           Status  Life_expectancy  Adult_Mortality  infant_deaths  Alcohol  \
# 0     Developing             65.0              263             62     0.01
# 1     Developing             59.9              271             64     0.01
# 2     Developing             59.9              268             66     0.01
# 3     Developing             59.5              272             69     0.01
# 4     Developing             59.2              275             71     0.01
# ...          ...              ...              ...            ...      ...
# 2918  Developing             50.0              587             30     4.64
# 2919  Developing             48.2              632             30     3.56
# 2920  Developing             46.6               67             29     3.88
# 2921  Developing             45.4                7             28     4.57
# 2922  Developing             44.6              717             28     4.14
#
#       percentage_expenditure  Hepatitis_B  Measles   BMI  under_five_deaths  \
# 0                  71.279624         65.0     1154  19.1                 83
# 1                  73.523582         62.0      492  18.6                 86
# 2                  73.219243         64.0      430  18.1                 89
# 3                  78.184215         67.0     2787  17.6                 93
# 4                   7.097109         68.0     3013  17.2                 97
# ...                      ...          ...      ...   ...                ...
# 2918                1.040021         73.0      853  29.0                 45
# 2919               20.843429         75.0        0  28.6                 46
# 2920               29.814566         72.0      242  28.2                 46
# 2921               34.262169         68.0      212  27.9                 45
# 2922                8.717409         65.0      420  27.5                 43
#
#       Polio  Total_expenditure  Diphtheria  HIV_AIDS         GDP  Population  \
# 0       6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1      58.0               8.18        62.0       0.1  612.696514  32758020.0
# 2      62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3      67.0               8.52        67.0       0.1  669.959000  30696958.0
# 4      68.0               7.87        68.0       0.1   63.537231  29708599.0
# ...     ...                ...         ...       ...         ...         ...
# 2918   69.0               6.26        73.0      18.1   65.824121  13810599.0
# 2919   75.0               4.96        75.0      20.5  325.678573  13558469.0
# 2920   73.0               4.47        73.0      23.7  396.998217  13329909.0
# 2921   71.0               5.12         7.0      26.8  414.796232  13124267.0
# 2922   69.0               6.44        68.0      30.3  444.765750  12940032.0
#
#       thinness_10_19_years  thinness_5_9_years  \
# 0                     17.2                17.3
# 1                     17.5                17.5
# 2                     17.7                17.7
# 3                     17.9                18.0
# 4                     18.2                18.2
# ...                    ...                 ...
# 2918                   7.5                 7.4
# 2919                   7.8                 7.8
# 2920                   8.2                 8.2
# 2921                   8.6                 8.6
# 2922                   9.0                 9.0
#
#       Income_composition_of_resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2918                            0.419        9.9
# 2919                            0.421        9.7
# 2920                            0.414        9.6
# 2921                            0.408        9.5
# 2922                            0.406        9.3
#
# [1848 rows x 20 columns]

# %%
df.loc[df['Status'] == "Developing", "Status"] = 0
df.loc[df['Status'] == "Developed", "Status"] = 1
df
# Out:
# C:\Users\Kathleen\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      Status  Life_expectancy  Adult_Mortality  infant_deaths  Alcohol  \
# 0         0             65.0              263             62     0.01
# 1         0             59.9              271             64     0.01
# 2         0             59.9              268             66     0.01
# 3         0             59.5              272             69     0.01
# 4         0             59.2              275             71     0.01
# ...     ...              ...              ...            ...      ...
# 2918      0             50.0              587             30     4.64
# 2919      0             48.2              632             30     3.56
# 2920      0             46.6               67             29     3.88
# 2921      0             45.4                7             28     4.57
# 2922      0             44.6              717             28     4.14
#
#       percentage_expenditure  Hepatitis_B  Measles   BMI  under_five_deaths  \
# 0                  71.279624         65.0     1154  19.1                 83
# 1                  73.523582         62.0      492  18.6                 86
# 2                  73.219243         64.0      430  18.1                 89
# 3                  78.184215         67.0     2787  17.6                 93
# 4                   7.097109         68.0     3013  17.2                 97
# ...                      ...          ...      ...   ...                ...
# 2918                1.040021         73.0      853  29.0                 45
# 2919               20.843429         75.0        0  28.6                 46
# 2920               29.814566         72.0      242  28.2                 46
# 2921               34.262169         68.0      212  27.9                 45
# 2922                8.717409         65.0      420  27.5                 43
#
#       Polio  Total_expenditure  Diphtheria  HIV_AIDS         GDP  Population  \
# 0       6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1      58.0               8.18        62.0       0.1  612.696514  32758020.0
# 2      62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3      67.0               8.52        67.0       0.1  669.959000  30696958.0
# 4      68.0               7.87        68.0       0.1   63.537231  29708599.0
# ...     ...                ...         ...       ...         ...         ...
# 2918   69.0               6.26        73.0      18.1   65.824121  13810599.0
# 2919   75.0               4.96        75.0      20.5  325.678573  13558469.0
# 2920   73.0               4.47        73.0      23.7  396.998217  13329909.0
# 2921   71.0               5.12         7.0      26.8  414.796232  13124267.0
# 2922   69.0               6.44        68.0      30.3  444.765750  12940032.0
#
#       thinness_10_19_years  thinness_5_9_years  \
# 0                     17.2                17.3
# 1                     17.5                17.5
# 2                     17.7                17.7
# 3                     17.9                18.0
# 4                     18.2                18.2
# ...                    ...                 ...
# 2918                   7.5                 7.4
# 2919                   7.8                 7.8
# 2920                   8.2                 8.2
# 2921                   8.6                 8.6
# 2922                   9.0                 9.0
#
#       Income_composition_of_resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2918                            0.419        9.9
# 2919                            0.421        9.7
# 2920                            0.414        9.6
# 2921                            0.408        9.5
# 2922                            0.406        9.3
#
# [1848 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

X = train.drop(["Life_expectancy"], axis=1)
Y = train["Life_expectancy"]
X
# Out:
#      Status  Adult_Mortality  infant_deaths  Alcohol  percentage_expenditure  \
# 2294      0              433             28     3.97               49.837127
# 853       0              298              6     0.61               17.357398
# 2133      0              256             15    11.05              162.808805
# 1202      0              181            124     0.09               22.847831
# 2216      0              217              0     4.14               49.936982
# ...     ...              ...            ...      ...                     ...
# 1758      0              155             26     0.46               71.116450
# 627       0               97              1     3.34             2568.237059
# 2693      0              211              7     2.48              385.325164
# 1651      0               29              8     0.01               62.484196
# 394       1               16              1    10.48              456.340466
#
#       Hepatitis_B  Measles   BMI  under_five_deaths  Polio  Total_expenditure  \
# 2294         84.0       31  21.2                 42   81.0              13.13
# 853           9.0       51  16.0                  9    9.0               3.24
# 2133         97.0      129  57.5                 17   98.0               6.83
# 1202         85.0     8419  25.6                148   86.0               2.93
# 2216         87.0        0  24.7                  0   98.0               7.44
# ...           ...      ...   ...                ...    ...                ...
# 1758         84.0     2724  45.7                 30   93.0               4.44
# 627          91.0        0  57.5                  1    9.0               9.56
# 2693         96.0        0  44.2                  8   96.0               1.99
# 1651          8.0       35  28.8                 12    8.0               3.36
# 394          96.0        3  59.7                  1   97.0               7.80
#
#       Diphtheria  HIV_AIDS          GDP   Population  thinness_10_19_years  \
# 2294        84.0       1.7   394.593244    6310260.0                   8.5
# 853          9.0       0.9   482.149940    4390840.0                   8.9
# 2133        97.0       0.2  1674.987710  142849449.0                   2.3
# 1202        85.0       0.3   362.663981  252032263.0                   1.5
# 2216        97.0       1.2   894.927988     163101.0                   6.7
# ...          ...       ...          ...          ...                   ...
# 1758        96.0       0.1  1336.775376   29181832.0                   6.7
# 627         91.0       0.1  9985.369590    4654122.0                   1.8
# 2693        96.0       0.1  4439.230000    5087210.0                   3.2
# 1651         8.0       1.2  1364.283745    3830239.0                   8.3
# 394         96.0       0.1  3893.689980    7658972.0                   2.2
#
#       thinness_5_9_years  Income_composition_of_resources  Schooling
# 2294                 8.4                            0.375        8.5
# 853                  8.8                            0.404        5.1
# 2133                 2.5                            0.773       13.7
# 1202                 1.3                            0.677       12.9
# 2216                 6.6                            0.527       10.3
# ...                  ...                              ...        ...
# 1758                 6.5                            0.530        8.5
# 627                  1.7                            0.758       13.6
# 2693                 3.3                            0.000       10.6
# 1651                 8.1                            0.491        7.8
# 394                  2.3                            0.745       13.5
#
# [1478 rows x 19 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor()

clf.fit(X, Y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
test_x = test.drop(["Life_expectancy"], axis=1)
test_y = test["Life_expectancy"]
predict_y = clf.predict(test_x)
predict_y
# Out:
# array([63.978, 66.705, 72.643, 76.144, 71.369, 74.196, 76.446, 64.792,
#        72.537, 71.888, 77.297, 83.582, 73.224, 67.806, 73.857, 77.736,
#        72.668, 79.254, 57.184, 73.318, 72.139, 67.133, 80.08 , 75.269,
#        69.948, 74.627, 54.109, 72.244, 74.262, 53.076, 69.497, 70.775,
#        73.556, 80.389, 71.082, 74.868, 74.739, 73.476, 53.996, 74.587,
#        66.177, 72.922, 73.358, 45.526, 74.196, 65.961, 76.184, 83.94 ,
#        51.382, 72.906, 74.105, 70.619, 75.266, 64.821, 69.912, 70.934,
#        61.845, 63.57 , 81.408, 73.704, 71.744, 75.792, 74.523, 71.846,
#        74.239, 73.219, 75.89 , 76.31 , 70.889, 65.22 , 71.697, 69.756,
#        67.775, 73.13 , 75.052, 76.953, 67.044, 80.428, 73.205, 58.839,
#        56.419, 68.384, 67.   , 75.131, 63.91 , 72.086, 47.231, 75.512,
#        64.398, 74.557, 78.422, 54.369, 77.066, 75.072, 56.646, 76.065,
#        73.502, 60.222, 59.78 , 79.301, 72.232, 76.575, 74.498, 67.837,
#        76.99 , 67.297, 63.776, 74.374, 75.187, 72.855, 82.963, 63.004,
#        74.347, 80.728, 72.32 , 73.827, 61.588, 62.41 , 64.986, 81.927,
#        73.234, 79.333, 58.538, 67.739, 76.01 , 72.324, 67.934, 72.592,
#        57.139, 69.283, 61.885, 63.944, 63.791, 77.234, 81.414, 57.284,
#        77.372, 64.793, 76.281, 72.053, 76.554, 63.656, 64.676, 79.213,
#        60.912, 67.45 , 76.048, 72.533, 65.916, 75.216, 62.541, 79.507,
#        81.584, 63.912, 81.009, 63.024, 77.811, 74.724, 58.235, 75.848,
#        77.466, 69.07 , 73.912, 69.798, 73.897, 61.545, 57.105, 54.135,
#        81.84 , 66.56 , 61.474, 70.92 , 51.12 , 74.081, 62.912, 81.401,
#        81.157, 70.931, 72.372, 82.492, 63.184, 73.67 , 63.614, 71.972,
#        74.345, 72.742, 73.602, 48.548, 74.286, 72.442, 73.352, 73.341,
#        51.834, 56.542, 62.317, 61.601, 73.635, 75.855, 59.758, 54.618,
#        74.167, 72.618, 78.144, 58.372, 77.086, 74.401, 52.999, 75.827,
#        79.325, 73.618, 57.183, 74.706, 74.212, 77.048, 78.772, 74.319,
#        73.275, 56.382, 73.313, 73.194, 72.219, 74.68 , 67.179, 72.886,
#        61.591, 80.223, 82.847, 47.002, 67.524, 82.109, 72.812, 59.568,
#        82.463, 76.193, 80.417, 64.349, 57.096, 73.509, 73.667, 70.606,
#        74.099, 70.531, 73.888, 73.19 , 67.862, 66.494, 74.83 , 66.74 ,
#        65.855, 70.606, 75.59 , 53.508, 72.099, 61.101, 76.393, 71.927,
#        73.207, 74.706, 74.85 , 75.757, 72.917, 65.65 , 71.905, 76.594,
#        47.447, 67.418, 69.877, 73.915, 79.568, 59.719, 50.48 , 82.575,
#        70.921, 74.835, 72.739, 69.286, 81.799, 73.873, 71.442, 72.163,
#        85.798, 51.543, 76.601, 52.296, 72.048, 81.055, 69.274, 72.604,
#        62.757, 70.054, 54.382, 78.65 , 73.294, 69.008, 77.243, 74.253,
#        65.248, 66.686, 74.032, 75.557, 71.819, 67.846, 68.022, 62.441,
#        58.149, 70.659, 58.834, 76.95 , 74.58 , 73.466, 74.174, 71.435,
#        68.434, 68.299, 57.253, 70.979, 73.355, 65.167, 72.511, 67.727,
#        63.456, 66.009, 74.133, 84.828, 62.086, 71.192, 64.06 , 74.665,
#        73.328, 73.892, 72.616, 82.509, 79.567, 72.417, 79.322, 72.934,
#        74.028, 67.882, 71.981, 78.96 , 72.874, 67.981, 51.602, 74.375,
#        68.528, 75.91 , 55.382, 75.893, 76.823, 73.572, 63.114, 79.643,
#        72.825, 60.606, 70.685, 72.954, 79.561, 50.635, 76.46 , 73.298,
#        78.781, 72.042, 75.446, 72.809, 77.292, 73.739, 73.338, 72.071,
#        64.932, 72.858])

# %%
import math
mse = test_y-predict_y
print(mse)
mse = (mse * mse)
print("mse = ",mse.mean())
print("rmse = ", math.sqrt(mse.mean()))
# Out:
# 472     1.022
# 1777   -0.305
# 1053    6.357
# 324     0.756
# 1677    0.131
#         ...
# 258    -3.939
# 1305    0.662
# 2570    0.429
# 1357   -0.232
# 2645    1.142
# Name: Life_expectancy, Length: 370, dtype: float64
# mse =  2.8739717918918997
# rmse =  1.6952792666377714

# %%
from matplotlib import pyplot as plt

mse.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('MSE histogram')
plt.xlabel('mean square error')
plt.ylabel('Counts')
plt.grid(axis='y', alpha=0.75)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

features = list(X.columns)
feature_imp = pd.Series(clf.feature_importances_,index=features).sort_values(ascending=True)
#print(feature_imp)

# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)

# Add labels to graph
plt.xlabel('Feature Importance Score by Random Forest')
plt.ylabel('Features')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
clf.score(test_x, test_y)
# Out:
# 0.9566806752387598
